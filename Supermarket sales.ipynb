# %%
#!pip install kaggle
#!pip install sqlalchemy psycopg2

# %%
#Descargar dataset csv desde Kaggle
import kaggle
# !kaggle datasets download aditirai2607/super-market-dataset -f "Sample - Superstore.csv"
# Out:
# ^C

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import kstest
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
import sklearn.cluster as cluster

# %%
df = pd.read_csv("Sample%20-%20Superstore.csv")
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  US-2021-103800  03-01-2021  07-01-2021  Standard Class    DP-13000
# 1       2  US-2021-112326  04-01-2021  08-01-2021  Standard Class    PO-19195
# 2       3  US-2021-112326  04-01-2021  08-01-2021  Standard Class    PO-19195
# 3       4  US-2021-112326  04-01-2021  08-01-2021  Standard Class    PO-19195
# 4       5  US-2021-141817  05-01-2021  12-01-2021  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States       Houston  ...       77095
# 1  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 2  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 3  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 4     Mick Brown     Consumer  United States  Philadelphia  ...       19143
#
#     Region       Product ID         Category Sub-Category  \
# 0  Central  OFF-PA-10000174  Office Supplies        Paper
# 1  Central  OFF-BI-10004094  Office Supplies      Binders
# 2  Central  OFF-LA-10003223  Office Supplies       Labels
# 3  Central  OFF-ST-10002743  Office Supplies      Storage
# 4     East  OFF-AR-10003478  Office Supplies          Art
#
#                                         Product Name    Sales  Quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448         2
# 1         GBC Standard Plastic Binding Systems Combs    3.540         2
# 2                                          Avery 508   11.784         3
# 3                      SAFCO Boltless Steel Shelving  272.736         3
# 4  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536         3
#
#    Discount   Profit
# 0       0.2   5.5512
# 1       0.8  -5.4870
# 2       0.2   4.2717
# 3       0.2 -64.7748
# 4       0.2   4.8840
#
# [5 rows x 21 columns]

# %%
#Ajustar nombres de columnas y eliminar columna customer_name
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(" ","_")
df["country"]=df["country/region"]
df["state"]=df["state/province"]
df["sub_category"]=df["sub-category"]
df=df.drop(columns=["customer_name", "country/region", "state/province","sub-category"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   row_id        10194 non-null  int64
#  1   order_id      10194 non-null  object
#  2   order_date    10194 non-null  object
#  3   ship_date     10194 non-null  object
#  4   ship_mode     10194 non-null  object
#  5   customer_id   10194 non-null  object
#  6   segment       10194 non-null  object
#  7   city          10194 non-null  object
#  8   postal_code   10194 non-null  object
#  9   region        10194 non-null  object
#  10  product_id    10194 non-null  object
#  11  category      10194 non-null  object
#  12  product_name  10194 non-null  object
#  13  sales         10194 non-null  float64
#  14  quantity      10194 non-null  int64
#  15  discount      10194 non-null  float64
#  16  profit        10194 non-null  float64
#  17  country       10194 non-null  object
#  18  state         10194 non-null  object
#  19  sub_category  10194 non-null  object
# dtypes: float64(3), int64(2), object(15)
# memory usage: 1.6+ MB

# %%
#Convertir order_date y ship_date a fechas
df["order_date"]=pd.to_datetime(df["order_date"],format="%d-%m-%Y")
df["ship_date"]=pd.to_datetime(df["ship_date"],format="%d-%m-%Y")

# %%
df.describe()
# Out:
#              row_id                     order_date  \
# count  10194.000000                          10194
# mean    5097.500000  2023-04-30 00:15:40.788699136
# min        1.000000            2021-01-03 00:00:00
# 25%     2549.250000            2022-05-14 00:00:00
# 50%     5097.500000            2023-06-25 00:00:00
# 75%     7645.750000            2024-05-14 00:00:00
# max    10194.000000            2024-12-30 00:00:00
# std     2942.898656                            NaN
#
#                            ship_date         sales      quantity  \
# count                          10194  10194.000000  10194.000000
# mean   2023-05-03 23:20:43.790465024    228.225854      3.791838
# min              2021-01-07 00:00:00      0.444000      1.000000
# 25%              2022-05-19 00:00:00     17.220000      2.000000
# 50%              2023-06-28 00:00:00     53.910000      3.000000
# 75%              2024-05-18 00:00:00    209.500000      5.000000
# max              2025-01-05 00:00:00  22638.480000     14.000000
# std                              NaN    619.906839      2.228317
#
#            discount        profit
# count  10194.000000  10194.000000
# mean       0.155385     28.673417
# min        0.000000  -6599.978000
# 25%        0.000000      1.760800
# 50%        0.200000      8.690000
# 75%        0.200000     29.297925
# max        0.800000   8399.976000
# std        0.206249    232.465115

# %%
#Detectar outliers en columnas numericas
sns.set_theme(style="darkgrid", palette="tab10")

cols = ["sales","quantity","discount","profit"]

fig, ax = plt.subplots(ncols=len(cols), figsize=(5 * len(cols),6), sharex = True)

for i in range(len(cols)):
  (sns.boxenplot(y=df[cols[i]],data=df, showfliers=True,ax=ax[i])).set(xlabel=cols[i])
  
fig.subplots_adjust(wspace=0.5)
plt.grid(True)
sns.despine()
# Out:
# 2025-02-05 23:50:34,208 WARNING Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000194DA46EA90>, 'Connection to www.kaggle.com timed out. (connect timeout=None)')': /api/v1/datasets/metadata/aditirai2607/super-market-dataset
# 2025-02-05 23:50:55,233 WARNING Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000194DAA3FC50>, 'Connection to www.kaggle.com timed out. (connect timeout=None)')': /api/v1/datasets/metadata/aditirai2607/super-market-dataset
# 2025-02-05 23:51:16,277 WARNING Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000194DAA583D0>, 'Connection to www.kaggle.com timed out. (connect timeout=None)')': /api/v1/datasets/metadata/aditirai2607/super-market-dataset
# Traceback (most recent call last):
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\urllib3\connection.py", line 203, in _new_conn
#     sock = connection.create_connection(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\urllib3\util\connection.py", line 85, in create_connection
#     raise err
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\urllib3\util\connection.py", line 73, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 791, in urlopen
#     response = self._make_request(
#                ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 492, in _make_request
#     raise new_e
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 468, in _make_request
#     self._validate_conn(conn)
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 1097, in _validate_conn
#     conn.connect()
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\urllib3\connection.py", line 611, in connect
#     self.sock = sock = self._new_conn()
#                        ^^^^^^^^^^^^^^^^
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\urllib3\connection.py", line 212, in _new_conn
#     raise ConnectTimeoutError(
# urllib3.exceptions.ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x00000194DAA58C10>, 'Connection to www.kaggle.com timed out. (connect timeout=None)')
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\jisot\anaconda3\Scripts\kaggle.exe\__main__.py", line 7, in <module>
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\kaggle\cli.py", line 63, in main
#     out = args.func(**command_args)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\kaggle\api\kaggle_api_extended.py", line 1571, in dataset_download_cli
#     self.metadata_get_with_http_info(owner_slug, dataset_slug))
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\kaggle\api\kaggle_api.py", line 3335, in metadata_get_with_http_info
#     return self.api_client.call_api(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\kaggle\api_client.py", line 313, in call_api
#     return self.__call_api(resource_path, method,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\kaggle\api_client.py", line 145, in __call_api
#     response_data = self.request(
#                     ^^^^^^^^^^^^^
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\kaggle\api_client.py", line 335, in request
#     return self.rest_client.GET(url,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\kaggle\rest.py", line 231, in GET
#     return self.request("GET", url,
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\kaggle\rest.py", line 204, in request
#     r = self.pool_manager.request(method, url,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\urllib3\_request_methods.py", line 110, in request
#     return self.request_encode_url(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\urllib3\_request_methods.py", line 143, in request_encode_url
#     return self.urlopen(method, url, **extra_kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\urllib3\poolmanager.py", line 443, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 875, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 875, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 875, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\urllib3\connectionpool.py", line 845, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\jisot\anaconda3\Lib\site-packages\urllib3\util\retry.py", line 515, in increment
#     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='www.kaggle.com', port=443): Max retries exceeded with url: /api/v1/datasets/metadata/aditirai2607/super-market-dataset (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000194DAA58C10>, 'Connection to www.kaggle.com timed out. (connect timeout=None)'))

# %%
# Eliminar outliers segun indice
index_names = df[(df["sales"] > 10000) | (df["profit"] > 4000) | (df["profit"] < -2600)].index
df.drop(index_names, inplace = True)
df.reset_index(drop= True, inplace=True)

# %%
#Segmentacion de clientes mediante KMeans

#Se consideran variables ship_mode, segment, category y region para segmentar
#Transformación a variables dummy para cada variable nominal

categorical_columns = ["ship_mode", "segment", "category", "region"]
one_hot_encoder = OneHotEncoder(handle_unknown="ignore", sparse_output=False)
one_hot_encoder.fit(df[categorical_columns])  
df_encoded = one_hot_encoder.transform(df[categorical_columns])

#Convertir a un nuevo dataframe
df_encoded = pd.DataFrame(df_encoded, columns=one_hot_encoder.get_feature_names_out())
df2=df[["customer_id","sales","quantity","discount","profit"]]
df2 = pd.concat([df2,df_encoded] , axis=1)

#Eliminar variables dummy redundantes
df2=df2.drop(["ship_mode_Standard Class","segment_Home Office","category_Technology","region_West"],axis=1)

# %%
#Agrupar por customer_id
df2=df2.groupby('customer_id').agg({
    "sales": "sum",   
    "quantity": "sum",
    "discount": "mean",
    "profit": "sum",
    "ship_mode_First Class": "mean",
    "ship_mode_Same Day": "mean",
    "ship_mode_Second Class": "mean",
    "segment_Consumer": "mean",
    "segment_Corporate": "mean",
    "category_Furniture": "mean",
    "category_Office Supplies": "mean",
    "region_Central": "mean",
    "region_East": "mean",
    "region_South": "mean",
}).reset_index()
df2.head()
# Out:
#   customer_id     sales  quantity  discount    profit  ship_mode_First Class  \
# 0    AA-10315  5563.560        30  0.090909 -362.8825               0.090909
# 1    AA-10375  1056.390        41  0.080000  277.3824               0.266667
# 2    AA-10480  1790.512        36  0.016667  435.8274               0.000000
# 3    AA-10645  5086.935        64  0.063889  857.8033               0.388889
# 4    AB-10015   886.156        13  0.066667  129.3465               0.833333
#
#    ship_mode_Same Day  ship_mode_Second Class  segment_Consumer  \
# 0            0.000000                     0.0               1.0
# 1            0.000000                     0.2               1.0
# 2            0.083333                     0.0               1.0
# 3            0.000000                     0.0               1.0
# 4            0.000000                     0.0               1.0
#
#    segment_Corporate  category_Furniture  category_Office Supplies  \
# 0                0.0            0.090909                  0.727273
# 1                0.0            0.066667                  0.733333
# 2                0.0            0.166667                  0.666667
# 3                0.0            0.444444                  0.444444
# 4                0.0            0.333333                  0.500000
#
#    region_Central  region_East  region_South
# 0        0.545455     0.181818      0.000000
# 1        0.133333     0.333333      0.266667
# 2        0.833333     0.083333      0.083333
# 3        0.166667     0.333333      0.222222
# 4        0.500000     0.000000      0.000000

# %%
#Normalizar columnas antes de aplicar KMeans
customer_id = df2[["customer_id"]]
df2 = df2.drop(columns=["customer_id"]) 
scaler = StandardScaler(copy = True, with_mean = True, with_std = True)
df2 = pd.DataFrame(scaler.fit_transform(df2), columns=df2.columns)
df2.head()
# Out:
#       sales  quantity  discount    profit  ship_mode_First Class  \
# 0  1.231514 -0.690092 -0.721825 -1.161190              -0.348894
# 1 -0.740812 -0.268165 -0.840282 -0.122204               0.603480
# 2 -0.419562 -0.459950 -1.527993  0.134911              -0.841502
# 3  1.022944  0.614046 -1.015226  0.819670               1.265763
# 4 -0.815306 -1.342161 -0.985063 -0.362428               3.674066
#
#    ship_mode_Same Day  ship_mode_Second Class  segment_Consumer  \
# 0           -0.465033               -0.934721           0.96576
# 1           -0.465033                0.036227           0.96576
# 2            0.272121               -0.934721           0.96576
# 3           -0.465033               -0.934721           0.96576
# 4           -0.465033               -0.934721           0.96576
#
#    segment_Corporate  category_Furniture  category_Office Supplies  \
# 0          -0.650391           -0.840101                  0.746410
# 1          -0.650391           -0.996739                  0.782446
# 2          -0.650391           -0.350606                  0.386049
# 3          -0.650391            1.444210                 -0.935272
# 4          -0.650391            0.726284                 -0.604942
#
#    region_Central  region_East  region_South
# 0        1.612001    -0.500932     -0.878412
# 1       -0.460720     0.136135      0.549052
# 2        3.059857    -0.915026     -0.432330
# 3       -0.293074     0.136135      0.311141
# 4        1.383392    -1.265413     -0.878412

# %%
# Analizar si existe correlacion entre variables 

#Test de normalidad
stat, p = kstest(df2['sales'], 'norm')
print(f"Sales K-S Test: p-value = {p}")
stat, p = kstest(df2['quantity'], 'norm')
print(f"quantity K-S Test: p-value = {p}")
stat, p = kstest(df2['discount'], 'norm')
print(f"discount K-S Test: p-value = {p}")
stat, p = kstest(df2['profit'], 'norm')
print(f"profit K-S Test: p-value = {p}")

#Se tiene que la data no distribuye normal, se utiliza correlación de spearman

# Heatmap
fig = plt.figure(figsize=(14,12))         
sns.heatmap(df2.corr(method="spearman"), annot = True,cmap = "Blues")

# Pairplot
sns.pairplot(df2[["sales","quantity","discount","profit"]])
sns.despine()
# Out:
# Sales K-S Test: p-value = 4.512964203730778e-10
# quantity K-S Test: p-value = 0.00019566038533071558
# discount K-S Test: p-value = 0.013333148359867625
# profit K-S Test: p-value = 1.969231771456835e-13

# %%
#Se observa una alta correlación entre sales y quantity, al igual que para sales y profit

# %%
#Aplicar KMeans
#Generar grafico de Elbow para determinar K optimo

# Probar valores de K
wcss = []
for k in range(1, 11):
    kmeans = cluster.KMeans(n_clusters=k, random_state=111, n_init=10)
    kmeans.fit(df2)
    wcss.append(kmeans.inertia_)  # Inertia = WCSS

# Generar grafico
plt.plot(range(1, 11), wcss, marker='o', linestyle='--')
plt.xlabel("Clusters (K)")
plt.ylabel("WCSS")
plt.show()

#Metodo de silhouette
silhouette_scores = []

for k in range(2, 11):  
    kmeans = cluster.KMeans(n_clusters=k, random_state=111, n_init=10)
    labels = kmeans.fit_predict(df2)
    score = silhouette_score(df2, labels)
    silhouette_scores.append(score)

# Generar grafico
plt.plot(range(2, 11), silhouette_scores, marker='o', linestyle='--')
plt.xlabel("Clusters (K)")
plt.ylabel("Silhouette Score")
plt.show()
# Out:
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
#Se considerará k=5

# %%
#Ajustar el algoritmo con el K elegido
K=5
kmeans = cluster.KMeans(n_clusters=K, init="k-means++",random_state=0)
kmeans.fit(df2)
df2['cluster'] = kmeans.labels_
df2 = pd.concat([customer_id, df2], axis=1)
# Out:
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\jisot\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %%
df = df.merge(df2[['customer_id', 'cluster']], on='customer_id', how='left')
df.head()
# Out:
#    row_id        order_id order_date  ship_date       ship_mode customer_id  \
# 0       1  US-2021-103800 2021-01-03 2021-01-07  Standard Class    DP-13000
# 1       2  US-2021-112326 2021-01-04 2021-01-08  Standard Class    PO-19195
# 2       3  US-2021-112326 2021-01-04 2021-01-08  Standard Class    PO-19195
# 3       4  US-2021-112326 2021-01-04 2021-01-08  Standard Class    PO-19195
# 4       5  US-2021-141817 2021-01-05 2021-01-12  Standard Class    MB-18085
#
#        segment          city postal_code   region  ...         category  \
# 0     Consumer       Houston       77095  Central  ...  Office Supplies
# 1  Home Office    Naperville       60540  Central  ...  Office Supplies
# 2  Home Office    Naperville       60540  Central  ...  Office Supplies
# 3  Home Office    Naperville       60540  Central  ...  Office Supplies
# 4     Consumer  Philadelphia       19143     East  ...  Office Supplies
#
#                                         product_name    sales  quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448         2
# 1         GBC Standard Plastic Binding Systems Combs    3.540         2
# 2                                          Avery 508   11.784         3
# 3                      SAFCO Boltless Steel Shelving  272.736         3
# 4  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536         3
#
#    discount   profit        country         state sub_category cluster
# 0       0.2   5.5512  United States         Texas        Paper       3
# 1       0.8  -5.4870  United States      Illinois      Binders       3
# 2       0.2   4.2717  United States      Illinois       Labels       3
# 3       0.2 -64.7748  United States      Illinois      Storage       3
# 4       0.2   4.8840  United States  Pennsylvania          Art       1
#
# [5 rows x 21 columns]

# %%
#Exportar a PostgreSQL

from sqlalchemy import create_engine

DATABASE_URL = "postgresql://postgres:Carlitos12@localhost:5432/supermarket_sales"
engine = create_engine(DATABASE_URL)

conn=engine.connect()

# %%
df.to_sql("df_sales", con=conn, index=False, if_exists='append')
# Out:
# 181

# %%
max_lengths = df.select_dtypes(include=['object']).apply(lambda col: col.str.len().max())
print(max_lengths)
# Out:
# order_id         14
# ship_mode        14
# customer_id       8
# segment          11
# city             17
# postal_code       5
# region            7
# product_id       15
# category         15
# product_name    127
# country          13
# state            25
# sub_category     11
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10181 entries, 0 to 10180
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   row_id        10181 non-null  int64
#  1   order_id      10181 non-null  object
#  2   order_date    10181 non-null  datetime64[ns]
#  3   ship_date     10181 non-null  datetime64[ns]
#  4   ship_mode     10181 non-null  object
#  5   customer_id   10181 non-null  object
#  6   segment       10181 non-null  object
#  7   city          10181 non-null  object
#  8   postal_code   10181 non-null  object
#  9   region        10181 non-null  object
#  10  product_id    10181 non-null  object
#  11  category      10181 non-null  object
#  12  product_name  10181 non-null  object
#  13  sales         10181 non-null  float64
#  14  quantity      10181 non-null  int64
#  15  discount      10181 non-null  float64
#  16  profit        10181 non-null  float64
#  17  country       10181 non-null  object
#  18  state         10181 non-null  object
#  19  sub_category  10181 non-null  object
#  20  cluster       10181 non-null  int32
# dtypes: datetime64[ns](2), float64(3), int32(1), int64(2), object(13)
# memory usage: 1.6+ MB
